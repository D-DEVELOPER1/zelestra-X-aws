# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
test_data = pd.read_csv("dataset/test.csv")
merge_data = pd.read_csv("dataset/train.csv")
merge_data.head()
# Out:
#    id  temperature  irradiance            humidity  panel_age  \
# 0   0     7.817315  576.179270   41.24308670850264  32.135501
# 1   1    24.785727  240.003973  1.3596482765960705  19.977460
# 2   2    46.652695  687.612799   91.26536837560256   1.496401
# 3   3    53.339567  735.141179   96.19095521176159  18.491582
# 4   4     5.575374   12.241203  27.495073003585226  30.722697
#
#    maintenance_count  soiling_ratio    voltage   current  module_temperature  \
# 0                4.0       0.803199  37.403527  1.963787           13.691147
# 1                8.0       0.479456  21.843315  0.241473           27.545096
# 2                4.0       0.822398  48.222882  4.191800           43.363708
# 3                3.0       0.837529  46.295748  0.960567           57.720436
# 4                6.0       0.551833   0.000000  0.898062            6.786263
#
#    cloud_coverage          wind_speed            pressure string_id  \
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20000 non-null  int64
#  1   temperature         18999 non-null  float64
#  2   irradiance          19013 non-null  float64
#  3   humidity            20000 non-null  object
#  4   panel_age           18989 non-null  float64
#  5   maintenance_count   18973 non-null  float64
#  6   soiling_ratio       18990 non-null  float64
#  7   voltage             19007 non-null  float64
#  8   current             19023 non-null  float64
#  9   module_temperature  19022 non-null  float64
#  10  cloud_coverage      18990 non-null  float64
#  11  wind_speed          20000 non-null  object
#  12  pressure            20000 non-null  object
#  13  string_id           20000 non-null  object
#  14  error_code          14088 non-null  object
# ...

# %%
pd.api.types.is_string_dtype(merge_data["humidity"])
# Out:
# True

# %%
for label, content in merge_data.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# humidity
# wind_speed
# pressure
# string_id

# %%
for label, content in merge_data.items():
    if pd.api.types.is_string_dtype(content):
        merge_data[label] = content.astype("category").cat.as_ordered()

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20000 non-null  int64
#  1   temperature         18999 non-null  float64
#  2   irradiance          19013 non-null  float64
#  3   humidity            20000 non-null  category
#  4   panel_age           18989 non-null  float64
#  5   maintenance_count   18973 non-null  float64
#  6   soiling_ratio       18990 non-null  float64
#  7   voltage             19007 non-null  float64
#  8   current             19023 non-null  float64
#  9   module_temperature  19022 non-null  float64
#  10  cloud_coverage      18990 non-null  float64
#  11  wind_speed          20000 non-null  category
#  12  pressure            20000 non-null  category
#  13  string_id           20000 non-null  category
#  14  error_code          14088 non-null  object
# ...

# %%
merge_data.drop(columns=["error_code", "installation_type", "error_code", "installation_type"], inplace = True)

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20000 non-null  int64
#  1   temperature         18999 non-null  float64
#  2   irradiance          19013 non-null  float64
#  3   humidity            20000 non-null  category
#  4   panel_age           18989 non-null  float64
#  5   maintenance_count   18973 non-null  float64
#  6   soiling_ratio       18990 non-null  float64
#  7   voltage             19007 non-null  float64
#  8   current             19023 non-null  float64
#  9   module_temperature  19022 non-null  float64
#  10  cloud_coverage      18990 non-null  float64
#  11  wind_speed          20000 non-null  category
#  12  pressure            20000 non-null  category
#  13  string_id           20000 non-null  category
#  14  efficiency          20000 non-null  float64
# ...

# %%
merge_data.to_csv("new_merge_data.csv", index = False)

# %%
pd.read_csv("new_merge_data.csv", low_memory = False)
merge_data.head()
# Out:
#    id  temperature  irradiance            humidity  panel_age  \
# 0   0     7.817315  576.179270   41.24308670850264  32.135501
# 1   1    24.785727  240.003973  1.3596482765960705  19.977460
# 2   2    46.652695  687.612799   91.26536837560256   1.496401
# 3   3    53.339567  735.141179   96.19095521176159  18.491582
# 4   4     5.575374   12.241203  27.495073003585226  30.722697
#
#    maintenance_count  soiling_ratio    voltage   current  module_temperature  \
# 0                4.0       0.803199  37.403527  1.963787           13.691147
# 1                8.0       0.479456  21.843315  0.241473           27.545096
# 2                4.0       0.822398  48.222882  4.191800           43.363708
# 3                3.0       0.837529  46.295748  0.960567           57.720436
# 4                6.0       0.551833   0.000000  0.898062            6.786263
#
#    cloud_coverage          wind_speed            pressure string_id  \
# ...

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20000 non-null  int64
#  1   temperature         18999 non-null  float64
#  2   irradiance          19013 non-null  float64
#  3   humidity            20000 non-null  category
#  4   panel_age           18989 non-null  float64
#  5   maintenance_count   18973 non-null  float64
#  6   soiling_ratio       18990 non-null  float64
#  7   voltage             19007 non-null  float64
#  8   current             19023 non-null  float64
#  9   module_temperature  19022 non-null  float64
#  10  cloud_coverage      18990 non-null  float64
#  11  wind_speed          20000 non-null  category
#  12  pressure            20000 non-null  category
#  13  string_id           20000 non-null  category
#  14  efficiency          20000 non-null  float64
# ...

# %%
merge_data["humidity"].cat.codes
# Out:
# 0         7111
# 1          269
# 2        18108
# 3        19088
# 4         4059
#          ...
# 19995    18527
# 19996    18634
# 19997     6300
# 19998     7486
# 19999     4346
# Length: 20000, dtype: int16

# %%
merge_data.isnull().sum()
# Out:
# id                       0
# temperature           1001
# irradiance             987
# humidity                 0
# panel_age             1011
# maintenance_count     1027
# soiling_ratio         1010
# voltage                993
# current                977
# module_temperature     978
# cloud_coverage        1010
# wind_speed               0
# pressure                 0
# string_id                0
# efficiency               0
# dtype: int64

# %%
for label, content in merge_data.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# id
# temperature
# irradiance
# panel_age
# maintenance_count
# soiling_ratio
# voltage
# current
# module_temperature
# cloud_coverage
# efficiency

# %%
for label, content in merge_data.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            merge_data[label] = content.fillna(content.median())

# %%
for label, content in merge_data.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)

# %%
for label, content in merge_data.items():
    if not pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)

# %%
for label, content in merge_data.items():
    if not pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            merge_data[label + "_is_missing"] = pd.isnull(content)
            merge_data[label] = pd.Categorical(content).codes+1

# %%
pd.Categorical(merge_data["humidity"]).codes+1
# Out:
# array([ 7112,   270, 18109, ...,  6301,  7487,  4347],
#       shape=(20000,), dtype=int16)

# %%
merge_data.isna().sum()
# Out:
# id                    0
# temperature           0
# irradiance            0
# humidity              0
# panel_age             0
# maintenance_count     0
# soiling_ratio         0
# voltage               0
# current               0
# module_temperature    0
# cloud_coverage        0
# wind_speed            0
# pressure              0
# string_id             0
# efficiency            0
# dtype: int64

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20000 non-null  int64
#  1   temperature         20000 non-null  float64
#  2   irradiance          20000 non-null  float64
#  3   humidity            20000 non-null  category
#  4   panel_age           20000 non-null  float64
#  5   maintenance_count   20000 non-null  float64
#  6   soiling_ratio       20000 non-null  float64
#  7   voltage             20000 non-null  float64
#  8   current             20000 non-null  float64
#  9   module_temperature  20000 non-null  float64
#  10  cloud_coverage      20000 non-null  float64
#  11  wind_speed          20000 non-null  category
#  12  pressure            20000 non-null  category
#  13  string_id           20000 non-null  category
#  14  efficiency          20000 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
merge_data['humidity'] = le.fit_transform(merge_data['humidity'])
merge_data['wind_speed'] = le.fit_transform(merge_data['wind_speed'])
merge_data['pressure'] = le.fit_transform(merge_data['pressure'])
merge_data['string_id'] = le.fit_transform(merge_data['string_id'])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# %%time
model = RandomForestRegressor(n_estimators = 100, n_jobs = -1, random_state = 42)
model.fit(merge_data.drop("efficiency", axis = 1), merge_data["efficiency"])
model.score(merge_data.drop("efficiency", axis = 1), merge_data["efficiency"])
# Out:
# CPU times: user 27.5 s, sys: 147 ms, total: 27.7 s
# Wall time: 3.75 s
# 0.9191247368986737

# %%
 merge_data.efficiency.value_counts()
# Out:
# efficiency
# 0.000000    631
# 0.562096      1
# 0.472342      1
# 0.574923      1
# 0.566042      1
#            ...
# 0.771724      1
# 0.395693      1
# 0.573411      1
# 0.437257      1
# 0.714566      1
# Name: count, Length: 19370, dtype: int64

# %%
merge_val = merge_data[merge_data.efficiency == 0.00000]
merge_train = merge_data[merge_data.efficiency != 0.00000]
len(merge_val), len(merge_train)
# Out:
# (631, 19369)

# %%
x_train, y_train = merge_train.drop("efficiency", axis = 1), merge_train.efficiency
x_valid, y_valid = merge_val.drop("efficiency", axis = 1), merge_val.efficiency

x_train.shape, y_train.shape, x_valid.shape, y_valid.shape
# Out:
# ((19369, 14), (19369,), (631, 14), (631,))

# %%
y_train
# Out:
# 0        0.562096
# 1        0.396447
# 2        0.573776
# 3        0.629009
# 4        0.341874
#            ...
# 19995    0.664907
# 19996    0.354070
# 19997    0.419734
# 19998    0.661963
# 19999    0.714566
# Name: efficiency, Length: 19369, dtype: float64

# %%
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score, mean_squared_error
def rmsle (y_test, y_preds):
    """
    """
    return np.sqrt(mean_absolute_error(y_test, y_preds))

def view_scores(model):
    train_preds = model.predict(x_train)
    val_preds = model.predict(x_valid)
    scores = {"Training MAE": mean_absolute_error(y_train, train_preds),
             "Valid MAE": mean_absolute_error(y_valid, val_preds),
             "Training RMSLE": rmsle(y_train, train_preds),
             "Valid RMSLE": rmsle(y_valid, val_preds),
             "Training R^2": r2_score(y_train, train_preds),
             "Valid R^2": r2_score(y_valid, val_preds),
             "Training MSE": mean_squared_error(y_train, train_preds),
             "Valid MSE": mean_squared_error(y_valid, val_preds)}
    return scores

# %%
# %%time
model=RandomForestRegressor(n_jobs = -1,
                            random_state = 42)
model.fit(x_train, y_train)
# Out:
# CPU times: user 21.9 s, sys: 114 ms, total: 22 s
# Wall time: 3.05 s
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
len(x_train)
# Out:
# 19369

# %%
x_train.shape[0]
# Out:
# 19369

# %%
view_scores(model)
# Out:
# {'Training MAE': 0.013256966763450066,
#  'Valid MAE': 0.520212746395551,
#  'Training RMSLE': np.float64(0.11513890204205555),
#  'Valid RMSLE': np.float64(0.7212577530921599),
#  'Training R^2': 0.9739854606380653,
#  'Valid R^2': 0.0,
#  'Training MSE': 0.0003017823904289608,
#  'Valid MSE': 0.27933111257337856}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# %%time
ideal_model = RandomForestRegressor(n_estimators = 40,
                                    min_samples_leaf = 1,
                                    min_samples_split = 14,
                                    max_features = 0.5,
                                    n_jobs = -1,
                                    max_samples = None,
                                    random_state = 42)
ideal_model.fit(x_train, y_train)
# Out:
# CPU times: user 4.15 s, sys: 16.8 ms, total: 4.17 s
# Wall time: 609 ms
# RandomForestRegressor(max_features=0.5, min_samples_split=14, n_estimators=40,
#                       n_jobs=-1, random_state=42)

# %%
view_scores(ideal_model)
# Out:
# {'Training MAE': 0.021951024463985048,
#  'Valid MAE': 0.5205473153956366,
#  'Training RMSLE': np.float64(0.14815878125843587),
#  'Valid RMSLE': np.float64(0.7214896502345939),
#  'Training R^2': 0.9289375463582821,
#  'Valid R^2': 0.0,
#  'Training MSE': 0.0008243619781761161,
#  'Valid MSE': 0.2794282622969976}

# %% [markdown]
# ## prediction on test data

# %%
test_preds = ideal_model(test_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 test_preds = ideal_model(test_data)
#
# TypeError: 'RandomForestRegressor' object is not callable

# %%
def preprocess_data(df):
        for label, content in df.items():
            if pd.api.types.is_numeric_dtype(content):
                if pd.isnull(content).sum():
                    df[label] = content.fillna(content.median())

        for label, content in df.items():
            if not pd.api.types.is_numeric_dtype(content):
                df[label] = pd.Categorical(content).codes + 1
    
        return df

# %%
test_data = preprocess_data(test_data)
test_data.head()
# Out:
#    id  temperature  irradiance  humidity  panel_age  maintenance_count  \
# 0   0    17.618379   85.449838     10829  13.910963                6.0
# 1   1    34.826323  722.801748      1675  20.916528                4.0
# 2   2    33.776934  485.491998      6160   1.446962                3.0
# 3   3    18.584189  350.022720      5250  18.810133                5.0
# 4   4    43.044908  437.295622      9385  17.402885                8.0
#
#    soiling_ratio    voltage   current  module_temperature  cloud_coverage  \
# 0       0.889765   6.370396  0.069101           19.517274       33.509889
# 1       0.590372  30.095867  1.713852           37.421443       32.327060
# 2       0.611425  28.424430  1.696936           32.147763       69.613333
# 3       0.697455   7.848038  0.787188           25.734118       42.862760
# 4       0.564938  12.300717  1.867620           29.952897       51.025763
#
#    wind_speed  pressure  string_id  error_code  installation_type
# ...

# %%
test_data.drop(columns=["error_code", "installation_type"], inplace = True)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
test_data['humidity'] = le.fit_transform(test_data['humidity'])
test_data['wind_speed'] = le.fit_transform(test_data['wind_speed'])
test_data['pressure'] = le.fit_transform(test_data['pressure'])
test_data['string_id'] = le.fit_transform(test_data['string_id'])

# %%
test_data.isna().sum()
# Out:
# id                    0
# temperature           0
# irradiance            0
# humidity              0
# panel_age             0
# maintenance_count     0
# soiling_ratio         0
# voltage               0
# current               0
# module_temperature    0
# cloud_coverage        0
# wind_speed            0
# pressure              0
# string_id             0
# error_code            0
# installation_type     0
# dtype: int64

# %%
test_preds = ideal_model.predict(test_data)

# %%
test_preds
# Out:
# array([0.40342559, 0.54890604, 0.53622568, ..., 0.65680012, 0.45933081,
#        0.55902855], shape=(12000,))

# %%
df_preds = pd.DataFrame(test_preds)

# %%
df_preds.columns = ["Efficiency"]

# %%
df_preds
# Out:
#        Efficiency
# 0        0.403426
# 1        0.548906
# 2        0.536226
# 3        0.475396
# 4        0.490910
# ...           ...
# 11995    0.567088
# 11996    0.479083
# 11997    0.656800
# 11998    0.459331
# 11999    0.559029
#
# [12000 rows x 1 columns]

# %%
df_preds.to_csv("efficiency.csv", index = False)

# %%
df_preds
# Out:
#        Efficiency
# 0        0.403426
# 1        0.548906
# 2        0.536226
# 3        0.475396
# 4        0.490910
# ...           ...
# 11995    0.567088
# 11996    0.479083
# 11997    0.656800
# 11998    0.459331
# 11999    0.559029
#
# [12000 rows x 1 columns]

# %%
ideal_model.feature_importances_
# Out:
# array([0.00955141, 0.01151502, 0.60087877, 0.01610746, 0.07368225,
#        0.00439238, 0.18506165, 0.01149053, 0.04438024, 0.01237038,
#        0.00938786, 0.00947199, 0.00962888, 0.0020812 ])

# %%
def plot_features(columns, importance, n = 14):
    df = (pd.DataFrame({"features": columns,
                        "features_importance": importance})
          .sort_values("features_importance", ascending = False)
          .reset_index(drop= True))
    fig, ax = plt.subplots()
    ax.barh(df["features"][:n], df["features_importance"][:14])
    ax.set_ylabel("features")
    ax.set_xlabel("features importance")
    ax.invert_yaxis()

# %%
plot_features(x_train.columns, ideal_model.feature_importances_)
