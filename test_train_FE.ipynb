# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Feature Engineering
# what we are going to cover in this section
# 1. Handing imbalance data
# 2. Treating the outiliers
# 3. Scaling the data
# 4. Converting the categorical features into no features

# %%
test_train_data = pd.read_csv("test_train_data.csv", low_memory = False)
test_train_data.head()
# Out:
#    id  temperature_x  irradiance_x         humidity_x  panel_age_x  \
# 0   0      17.618379     85.449838  90.81542277591531    13.910963
# 1   1      34.826323    722.801748  20.98299301574633    20.916528
# 2   2      33.776934    485.491998  55.61404977577451     1.446962
# 3   3      18.584189    350.022720  49.04476645510075    18.810133
# 4   4      43.044908    437.295622  8.761571340027164    17.473594
#
#    maintenance_count_x  soiling_ratio_x  voltage_x  current_x  \
# 0                  6.0         0.889765   6.370396   0.069101
# 1                  4.0         0.590372  30.095867   1.713852
# 2                  3.0         0.611425  28.424430   1.696936
# 3                  5.0         0.700468   7.848038   0.787188
# 4                  8.0         0.564938  12.300717   1.867620
#
#    module_temperature_x  ...  voltage_y current_y module_temperature_y  \
# 0             19.517274  ...  37.403527  1.963787            13.691147
# ...

# %%
test_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    12000 non-null  int64
#  1   temperature_x         12000 non-null  float64
#  2   irradiance_x          12000 non-null  float64
#  3   humidity_x            12000 non-null  object
#  4   panel_age_x           12000 non-null  float64
#  5   maintenance_count_x   12000 non-null  float64
#  6   soiling_ratio_x       12000 non-null  float64
#  7   voltage_x             12000 non-null  float64
#  8   current_x             12000 non-null  float64
#  9   module_temperature_x  12000 non-null  float64
#  10  cloud_coverage_x      12000 non-null  float64
#  11  wind_speed_x          12000 non-null  object
#  12  pressure_x            12000 non-null  object
#  13  string_id_x           12000 non-null  object
# ...

# %%
test_train_data.isnull().sum()
# Out:
# id                      0
# temperature_x           0
# irradiance_x            0
# humidity_x              0
# panel_age_x             0
# maintenance_count_x     0
# soiling_ratio_x         0
# voltage_x               0
# current_x               0
# module_temperature_x    0
# cloud_coverage_x        0
# wind_speed_x            0
# pressure_x              0
# string_id_x             0
# error_code_x            0
# installation_type_x     0
# temperature_y           0
# irradiance_y            0
# humidity_y              0
# panel_age_y             0
# maintenance_count_y     0
# soiling_ratio_y         0
# voltage_y               0
# current_y               0
# module_temperature_y    0
# cloud_coverage_y        0
# wind_speed_y            0
# pressure_y              0
# string_id_y             0
# error_code_y            0
# installation_type_y     0
# efficiency              0
# dtype: int64

# %%
test_train_data.isnull().sum()
# Out:
# id                      0
# temperature_x           0
# irradiance_x            0
# humidity_x              0
# panel_age_x             0
# maintenance_count_x     0
# soiling_ratio_x         0
# voltage_x               0
# current_x               0
# module_temperature_x    0
# cloud_coverage_x        0
# wind_speed_x            0
# pressure_x              0
# string_id_x             0
# error_code_x            0
# installation_type_x     0
# temperature_y           0
# irradiance_y            0
# humidity_y              0
# panel_age_y             0
# maintenance_count_y     0
# soiling_ratio_y         0
# voltage_y               0
# current_y               0
# module_temperature_y    0
# cloud_coverage_y        0
# wind_speed_y            0
# pressure_y              0
# string_id_y             0
# error_code_y            0
# installation_type_y     0
# efficiency              0
# dtype: int64

# %%
test_train_data["wind_speed_x"]
# Out:
# array(['7.1819582155525445', '4.184581989921003', '6.25944104775485', ...,
#        '14.3559453768628', '6.95866488523872', '6.169192526827322'],
#       shape=(11922,), dtype=object)
